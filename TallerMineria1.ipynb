# %% [markdown]
# <a href="https://colab.research.google.com/github/RSoto3/MineriaTaller1/blob/main/TallerMineria1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# #Lectura de datos

# %%
import numpy as np
import pandas as pd
# For visualizations
import matplotlib.pyplot as plt
# For regular expressions
import re
# For handling string
import string
# For performing mathematical operations
import math

# Importing dataset
df=pd.read_csv('Licencias_Medicas_2022t2.txt', sep = "|")
df.isnull().sum()
print("Shape of data=>",df.shape)
df.columns = ['Codigo Isapre','Fecha Informacion','Run Trabajador','Fecha emision licencia','Numero de dias','Fecha inicio reposo','Edad trabajador','Sexo trabajador','Actividad laboral','Ocupacion','Tipo de licencia','Caracteristicas del reposo','Run profesional','Tipo profesional','Tipo licencia segun contraloria','Numero de dias autorizados','Diagnostico principal','Tipo de resolucion','Periodo','Reposo autorizado','Derecho a subsidio','Fecha recepcion isapre','Fecha resolucion isapre','Fecha recepcion empleador','Region','Calidad Trabajador','Entidad pagadora','Numero dias a pagar','Monto subsidio liquido','Monto aporte previsional isapre','Fecha de inicio del pago','Recuperabilidad','Fecha de concepcion','Monto aporte previsional de pensiones','Otros diagnosticos','Run identificacion del hijo','Lugar reposo','Causa rechazo o modificacion','Numero de dias previos autorizados','Fecha primera afiliacion entidad previsional','Fecha contrado de trabajo','Monto base calculo subsidio','Rut Empleador','Fecha nacimiento hijo','borrar']
# Out:
# Shape of data=> (5526, 45)

# %%
df = df.drop('borrar', axis=1)
df = df.drop('Otros diagnosticos', axis=1)
df = df[df['Diagnostico principal'].notna()]

# %%
df
# Out:
#         Codigo Isapre Fecha Informacion  Run Trabajador  \
# 0                  67            2022t2         3078522
# 1                 107            2022t2        40458254
# 2                 107            2022t2         2979082
# 3                 107            2022t2         2081595
# 4                 107            2022t2         2979082
# ...               ...               ...             ...
# 573487             67            2022t2         2067953
# 573488             99            2022t2         7024059
# 573489            107            2022t2         3222173
# 573490             99            2022t2         2819663
# 573491             99            2022t2         1113896
#
#        Fecha emision licencia  Numero de dias Fecha inicio reposo  \
# 0                      2022t2               7              2022t2
# 1                      2022t2               7              2022t2
# 2                      2022t1               5              2022t1
# 3                      2022t2              15              2022t2
# 4                      2022t2              12              2022t2
# ...                       ...             ...                 ...
# 573487                 2022t2              14              2022t2
# 573488                 2022t2               3              2022t2
# 573489                 2022t2               2              2022t2
# 573490                 2022t2               7              2022t2
# 573491                 2022t2               7              2022t2
#
#        Edad trabajador Sexo trabajador Actividad laboral         Ocupacion  \
# 0                36-40        Femenino        Transporte          Profesor
# 1                31-35       Masculino        Transporte          Profesor
# 2                41-45        Femenino        Transporte          Profesor
# 3                31-35        Femenino        Transporte          Profesor
# 4                41-45        Femenino        Transporte          Profesor
# ...                ...             ...               ...               ...
# 573487           46-50        Femenino          Finanzas  Otro Profesional
# 573488           31-35       Masculino          Finanzas  Otro Profesional
# 573489           41-45       Masculino          Finanzas  Otro Profesional
# 573490           31-35       Masculino          Finanzas  Otro Profesional
# 573491           31-35        Femenino         Servicios  Otro Profesional
#
#         ... Monto aporte previsional de pensiones Run identificacion del hijo  \
# 0       ...                                 43103                     1529982
# 1       ...                                 27583                     1529982
# 2       ...                                 17391                     1529982
# 3       ...                                 63917                     1529982
# 4       ...                                 52973                     1529982
# ...     ...                                   ...                         ...
# 573487  ...                                     0                     1529982
# 573488  ...                                 30037                     1529982
# 573489  ...                                     0                     1529982
# 573490  ...                                 65331                     1529982
# 573491  ...                                 64817                     1529982
#
#         Lugar reposo Causa rechazo o modificacion  \
# 0       Su Domicilio            Z. Sin Clasificar
# 1       Su Domicilio            Z. Sin Clasificar
# 2       Su Domicilio            Z. Sin Clasificar
# 3       Su Domicilio            Z. Sin Clasificar
# 4       Su Domicilio            Z. Sin Clasificar
# ...              ...                          ...
# 573487  Su Domicilio            Z. Sin Clasificar
# 573488  Su Domicilio            Z. Sin Clasificar
# 573489  Su Domicilio            Z. Sin Clasificar
# 573490  Su Domicilio            Z. Sin Clasificar
# 573491  Su Domicilio            Z. Sin Clasificar
#
#        Numero de dias previos autorizados  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ...                                   ...
# 573487                                  0
# 573488                                  0
# 573489                                  0
# 573490                                  0
# 573491                                  0
#
#         Fecha primera afiliacion entidad previsional  \
# 0                                             2013t1
# 1                                             2017t1
# 2                                             2020t1
# 3                                             2013t1
# 4                                             2020t1
# ...                                              ...
# 573487                                        2001t1
# 573488                                        2007t4
# 573489                                        2005t1
# 573490                                        2013t1
# 573491                                        2018t3
#
#        Fecha contrado de trabajo Monto base calculo subsidio Rut Empleador  \
# 0                         2013t1                      858167     261926630
# 1                         2017t1                     1092870     261926630
# 2                         2020t1                     1243330     261926630
# 3                         2013t1                      750894     261926630
# 4                         2020t1                      904200     261926630
# ...                          ...                         ...           ...
# 573487                    2008t1                     1981877       6599107
# 573488                    2017t2                     2044308       6599107
# 573489                    2010t1                           0       6599107
# 573490                    2017t1                     2084345       6599107
# 573491                    2022t2                     1864626       6599107
#
#        Fecha nacimiento hijo
# 0                       1800
# 1                       1800
# 2                       1800
# 3                       1800
# 4                       1800
# ...                      ...
# 573487                  1800
# 573488                  1800
# 573489                  1800
# 573490                  1800
# 573491                  1800
#
# [561751 rows x 43 columns]

# %%
df.isnull().sum()
# Out:
# Codigo Isapre                                   0
# Fecha Informacion                               0
# Run Trabajador                                  0
# Fecha emision licencia                          0
# Numero de dias                                  0
# Fecha inicio reposo                             0
# Edad trabajador                                 0
# Sexo trabajador                                 0
# Actividad laboral                               0
# Ocupacion                                       0
# Tipo de licencia                                0
# Caracteristicas del reposo                      0
# Run profesional                                 0
# Tipo profesional                                0
# Tipo licencia segun contraloria                 0
# Numero de dias autorizados                      0
# Diagnostico principal                           0
# Tipo de resolucion                              0
# Periodo                                         0
# Reposo autorizado                               0
# Derecho a subsidio                              0
# Fecha recepcion isapre                          0
# Fecha resolucion isapre                         0
# Fecha recepcion empleador                       0
# Region                                          0
# Calidad Trabajador                              0
# Entidad pagadora                                0
# Numero dias a pagar                             0
# Monto subsidio liquido                          0
# Monto aporte previsional isapre                 0
# Fecha de inicio del pago                        0
# Recuperabilidad                                 0
# Fecha de concepcion                             0
# Monto aporte previsional de pensiones           0
# Run identificacion del hijo                     0
# Lugar reposo                                    0
# Causa rechazo o modificacion                    0
# Numero de dias previos autorizados              0
# Fecha primera afiliacion entidad previsional    0
# Fecha contrado de trabajo                       0
# Monto base calculo subsidio                     0
# Rut Empleador                                   0
# Fecha nacimiento hijo                           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 561751 entries, 0 to 573491
# Data columns (total 43 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   Codigo Isapre                                 561751 non-null  int64
#  1   Fecha Informacion                             561751 non-null  object
#  2   Run Trabajador                                561751 non-null  int64
#  3   Fecha emision licencia                        561751 non-null  object
#  4   Numero de dias                                561751 non-null  int64
#  5   Fecha inicio reposo                           561751 non-null  object
#  6   Edad trabajador                               561751 non-null  object
#  7   Sexo trabajador                               561751 non-null  object
#  8   Actividad laboral                             561751 non-null  object
#  9   Ocupacion                                     561751 non-null  object
#  10  Tipo de licencia                              561751 non-null  object
#  11  Caracteristicas del reposo                    561751 non-null  object
#  12  Run profesional                               561751 non-null  int64
#  13  Tipo profesional                              561751 non-null  object
#  14  Tipo licencia segun contraloria               561751 non-null  object
#  15  Numero de dias autorizados                    561751 non-null  int64
#  16  Diagnostico principal                         561751 non-null  object
#  17  Tipo de resolucion                            561751 non-null  object
#  18  Periodo                                       561751 non-null  object
#  19  Reposo autorizado                             561751 non-null  object
#  20  Derecho a subsidio                            561751 non-null  object
#  21  Fecha recepcion isapre                        561751 non-null  object
#  22  Fecha resolucion isapre                       561751 non-null  object
#  23  Fecha recepcion empleador                     561751 non-null  object
#  24  Region                                        561751 non-null  int64
#  25  Calidad Trabajador                            561751 non-null  object
#  26  Entidad pagadora                              561751 non-null  object
#  27  Numero dias a pagar                           561751 non-null  int64
#  28  Monto subsidio liquido                        561751 non-null  int64
#  29  Monto aporte previsional isapre               561751 non-null  int64
#  30  Fecha de inicio del pago                      561751 non-null  object
#  31  Recuperabilidad                               561751 non-null  object
#  32  Fecha de concepcion                           561751 non-null  int64
#  33  Monto aporte previsional de pensiones         561751 non-null  int64
#  34  Run identificacion del hijo                   561751 non-null  int64
#  35  Lugar reposo                                  561751 non-null  object
#  36  Causa rechazo o modificacion                  561751 non-null  object
#  37  Numero de dias previos autorizados            561751 non-null  int64
#  38  Fecha primera afiliacion entidad previsional  561751 non-null  object
#  39  Fecha contrado de trabajo                     561751 non-null  object
#  40  Monto base calculo subsidio                   561751 non-null  int64
#  41  Rut Empleador                                 561751 non-null  int64
#  42  Fecha nacimiento hijo                         561751 non-null  int64
# dtypes: int64(16), object(27)
# memory usage: 188.6+ MB

# %%
print(df.loc[df['Fecha nacimiento hijo'] != 1800])
# Out:
#       Codigo Isapre Fecha Informacion  Run Trabajador Fecha emision licencia  \
# 72              107            2022t2         1388903                 2022t2
# 79              107            2022t2          608609                 2022t2
# 125              67            2022t2       261976351                 2022t2
# 126              67            2022t2       261976351                 2022t2
# 127              67            2022t2       261976351                 2022t2
# ...             ...               ...             ...                    ...
# 5207             78            2022t2         2896175                 2022t2
# 5208             78            2022t2         2896175                 2022t2
# 5211            107            2022t2       261164792                 2022t2
# 5254             67            2022t2          266265                 2022t2
# 5525             81            2022t2         1062420                 2022t2
#
#       Numero de dias Fecha inicio reposo Edad trabajador Sexo trabajador  \
# 72                84              2022t2           26-30        Femenino
# 79                84              2022t2           31-35        Femenino
# 125               30              2022t2           26-30        Femenino
# 126               30              2022t2           26-30        Femenino
# 127               30              2022t2           26-30        Femenino
# ...              ...                 ...             ...             ...
# 5207               7              2022t2           36-40        Femenino
# 5208              30              2022t2           36-40        Femenino
# 5211              84              2022t2           36-40        Femenino
# 5254              84              2022t1           26-30        Femenino
# 5525               3              2022t2           66-70        Femenino
#
#      Actividad laboral         Ocupacion  ... Run identificacion del hijo  \
# 72               Otros  Otro Profesional  ...                2.011087e+09
# 79            Finanzas          Profesor  ...                2.011054e+09
# 125              Otros          Profesor  ...                2.010988e+09
# 126              Otros          Profesor  ...                2.010988e+09
# 127              Otros  Otro Profesional  ...                2.010988e+09
# ...                ...               ...  ...                         ...
# 5207             Otros          Profesor  ...                2.011044e+09
# 5208             Otros          Profesor  ...                2.011044e+09
# 5211             Otros          Profesor  ...                2.011052e+09
# 5254             Otros          Profesor  ...                2.011088e+09
# 5525             Otros             Otros  ...                         NaN
#
#       Lugar reposo  Causa rechazo o modificacion  \
# 72    Su Domicilio             Z. Sin Clasificar
# 79    Su Domicilio             Z. Sin Clasificar
# 125   Su Domicilio             Z. Sin Clasificar
# 126   Su Domicilio          Reposo Injustificado
# 127   Su Domicilio          Reposo Injustificado
# ...            ...                           ...
# 5207  Su Domicilio             Z. Sin Clasificar
# 5208  Su Domicilio             Z. Sin Clasificar
# 5211  Su Domicilio             Z. Sin Clasificar
# 5254  Su Domicilio             Z. Sin Clasificar
# 5525           NaN                           NaN
#
#      Numero de dias previos autorizados  \
# 72                                 25.0
# 79                                115.0
# 125                                 0.0
# 126                                 0.0
# 127                                35.0
# ...                                 ...
# 5207                              231.0
# 5208                              245.0
# 5211                              125.0
# 5254                               42.0
# 5525                                NaN
#
#      Fecha primera afiliacion entidad previsional  Fecha contrado de trabajo  \
# 72                                         2018t1                     2019t1
# 79                                         2017t4                     2019t1
# 125                                        2013t1                     2019t4
# 126                                        2013t1                     2019t4
# 127                                        2013t1                     2019t4
# ...                                           ...                        ...
# 5207                                       2006t1                     2010t1
# 5208                                       2006t1                     2010t1
# 5211                                       2013t2                     2020t1
# 5254                                       2015t4                     2021t1
# 5525                                          NaN                        NaN
#
#      Monto base calculo subsidio Rut Empleador Fecha nacimiento hijo borrar
# 72                      193023.0  2.619266e+08                2022.0    NaN
# 79                      433420.0  2.624631e+08                2022.0    NaN
# 125                     556988.0  2.624631e+08                2021.0    NaN
# 126                          0.0  2.624631e+08                2021.0    NaN
# 127                     534624.0  2.624631e+08                2021.0    NaN
# ...                          ...           ...                   ...    ...
# 5207                   1021668.0  6.618749e+06                2021.0    NaN
# 5208                   1021668.0  6.618749e+06                2021.0    NaN
# 5211                    675970.0  2.010918e+09                2022.0    NaN
# 5254                    851136.0  2.624782e+08                2022.0    NaN
# 5525                         NaN           NaN                   NaN    NaN
#
# [281 rows x 45 columns]
